# %%
from ultralytics import YOLO
import os
import numpy as np
from sklearn.metrics import accuracy_score, precision_recall_fscore_support
import cv2
import torch
import matplotlib.pyplot as plt

# %%
#Loading YOLO image classifcation model
model=YOLO('yolov8n-cls.pt')

# %%
#Training the Image-based dog emotion classifier for 50 epochs
#model.train(data=r"dog_image_dataset_preprocessed", epochs=50, imgsz=256)
# Out:
# New https://pypi.org/project/ultralytics/8.3.80 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.11.9 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
#Evaluation Metrics for the Image-based dog emotion classifier for 50 epochs
#model_path = r"runs\classify\train\weights\best.pt"
#model = YOLO(model_path)
#class_labels = {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
#test_dir = r"dog_image_dataset_preprocessed\val"
#y_true = []
#y_pred = []
#for class_name in class_labels.values():
#    class_path = os.path.join(test_dir, class_name)
#    if not os.path.exists(class_path):
#        continue
#    for filename in os.listdir(class_path):
#        if filename.endswith(('.jpg', '.png')):  
#            y_true.append(class_name)  
#            img_path = os.path.join(class_path, filename)
#            results = model(img_path)
#            predicted_index = results[0].probs.top1  
#            predicted_label = class_labels[predicted_index]              
#            y_pred.append(predicted_label)
#y_true = np.array(y_true)
#y_pred = np.array(y_pred)
#accuracy = accuracy_score(y_true, y_pred)
#precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted", zero_division=1)
#print(f"Accuracy: {accuracy:.4f}")
#print(f"Precision: {precision:.4f}")
#print(f"Recall: {recall:.4f}")
#print(f"F1 Score: {f1:.4f}")
# Out:
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0da4j6Ehkb6Ml0YBRiWmsBU2wEMoXP409.jpg: 256x256 angry 1.00, happy 0.00, relaxed 0.00, sad 0.00, 6.7ms
# Speed: 2.9ms preprocess, 6.7ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0jgI6KwR6IGvq9CAMBB3srLRa0W7z7192.jpg: 256x256 angry 0.95, sad 0.03, relaxed 0.01, happy 0.01, 4.2ms
# Speed: 2.6ms preprocess, 4.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0RXraPIKC00Dz1qkuMbj8XbuR80g5Z893.jpg: 256x256 angry 1.00, sad 0.00, happy 0.00, relaxed 0.00, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 256)
#
# ...

# %%
#Predictions

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train\weights\best.pt")
image_path = r"To_be_predicted_images\images.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.75, sad 0.25, happy 0.00, angry 0.00, 6.6ms
# Speed: 0.5ms preprocess, 6.6ms inference, 1.8ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([4.2995e-06, 2.7464e-05, 7.4877e-01, 2.5120e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.7488, device='cuda:0')
# top5: [2, 3, 1, 0]
# top5conf: tensor([7.4877e-01, 2.5120e-01, 2.7464e-05, 4.2995e-06], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train\weights\best.pt")
image_path = r"To_be_predicted_images\images1.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 happy 0.47, relaxed 0.36, angry 0.13, sad 0.05, 7.7ms
# Speed: 0.8ms preprocess, 7.7ms inference, 1.1ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([0.1289, 0.4683, 0.3568, 0.0460], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 1
# top1conf: tensor(0.4683, device='cuda:0')
# top5: [1, 2, 0, 3]
# top5conf: tensor([0.4683, 0.3568, 0.1289, 0.0460], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train\weights\best.pt")
image_path = r"To_be_predicted_images\images2.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 sad 0.89, relaxed 0.11, happy 0.00, angry 0.00, 12.7ms
# Speed: 0.8ms preprocess, 12.7ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([9.6319e-05, 2.1812e-04, 1.0733e-01, 8.9236e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 3
# top1conf: tensor(0.8924, device='cuda:0')
# top5: [3, 2, 1, 0]
# top5conf: tensor([8.9236e-01, 1.0733e-01, 2.1812e-04, 9.6319e-05], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train\weights\best.pt")
image_path = r"To_be_predicted_images\images3.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 angry 1.00, happy 0.00, relaxed 0.00, sad 0.00, 9.3ms
# Speed: 2.9ms preprocess, 9.3ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([1.0000e+00, 3.2372e-06, 1.7036e-08, 9.9916e-09], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 0
# top1conf: tensor(1.0000, device='cuda:0')
# top5: [0, 1, 2, 3]
# top5conf: tensor([1.0000e+00, 3.2372e-06, 1.7036e-08, 9.9916e-09], device='cuda:0')

# %%
#Training the Image-based dog emotion classifier for 100 epochs
#model.train(data=r"C:\Users\sujay\Desktop\project_2\dog_image_dataset_preprocessed", epochs=100, imgsz=256)
# Out:
# New https://pypi.org/project/ultralytics/8.3.80 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.11.9 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
#Evaluation Metrics for the Image-based dog emotion classifier for 50 epochs
#model_path = r"runs\classify\train2\weights\best.pt"
#model = YOLO(model_path)
#class_labels = {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
#test_dir = r"dog_image_dataset_preprocessed\val"
#y_true = []
#y_pred = []
#for class_name in class_labels.values():
#    class_path = os.path.join(test_dir, class_name)
#    if not os.path.exists(class_path):
#        continue
#    for filename in os.listdir(class_path):
#        if filename.endswith(('.jpg', '.png')):  
#            y_true.append(class_name)  
#            img_path = os.path.join(class_path, filename)
#            results = model(img_path)
#            predicted_index = results[0].probs.top1  
#            predicted_label = class_labels[predicted_index]              
#            y_pred.append(predicted_label)
#y_true = np.array(y_true)
#y_pred = np.array(y_pred)
#accuracy = accuracy_score(y_true, y_pred)
#precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted", zero_division=1)
#print(f"Accuracy: {accuracy:.4f}")
#print(f"Precision: {precision:.4f}")
#print(f"Recall: {recall:.4f}")
#print(f"F1 Score: {f1:.4f}")
# Out:
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0da4j6Ehkb6Ml0YBRiWmsBU2wEMoXP409.jpg: 256x256 angry 0.99, happy 0.01, relaxed 0.00, sad 0.00, 5.1ms
# Speed: 2.4ms preprocess, 5.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0jgI6KwR6IGvq9CAMBB3srLRa0W7z7192.jpg: 256x256 angry 0.98, happy 0.01, relaxed 0.01, sad 0.00, 3.7ms
# Speed: 2.1ms preprocess, 3.7ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0RXraPIKC00Dz1qkuMbj8XbuR80g5Z893.jpg: 256x256 angry 1.00, sad 0.00, happy 0.00, relaxed 0.00, 5.2ms
# Speed: 2.3ms preprocess, 5.2ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# ...

# %%
#Predictions

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train2\weights\best.pt")
image_path = r"To_be_predicted_images\images.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.68, sad 0.32, angry 0.00, happy 0.00, 10.8ms
# Speed: 3.3ms preprocess, 10.8ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([1.2981e-05, 1.7617e-06, 6.8481e-01, 3.1517e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.6848, device='cuda:0')
# top5: [2, 3, 0, 1]
# top5conf: tensor([6.8481e-01, 3.1517e-01, 1.2981e-05, 1.7617e-06], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train2\weights\best.pt")
image_path = r"To_be_predicted_images\images1.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.73, happy 0.22, angry 0.05, sad 0.00, 3.6ms
# Speed: 0.3ms preprocess, 3.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([4.8667e-02, 2.1867e-01, 7.3265e-01, 1.3427e-05], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.7327, device='cuda:0')
# top5: [2, 1, 0, 3]
# top5conf: tensor([7.3265e-01, 2.1867e-01, 4.8667e-02, 1.3427e-05], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train2\weights\best.pt")
image_path = r"To_be_predicted_images\images2.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.83, sad 0.15, happy 0.02, angry 0.00, 6.5ms
# Speed: 1.3ms preprocess, 6.5ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([2.5684e-04, 2.1320e-02, 8.2641e-01, 1.5201e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.8264, device='cuda:0')
# top5: [2, 3, 1, 0]
# top5conf: tensor([8.2641e-01, 1.5201e-01, 2.1320e-02, 2.5684e-04], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train2\weights\best.pt")
image_path = r"To_be_predicted_images\images3.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 angry 1.00, happy 0.00, relaxed 0.00, sad 0.00, 12.8ms
# Speed: 3.1ms preprocess, 12.8ms inference, 1.0ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([9.9998e-01, 1.8430e-05, 1.9339e-08, 1.7298e-09], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 0
# top1conf: tensor(1.0000, device='cuda:0')
# top5: [0, 1, 2, 3]
# top5conf: tensor([9.9998e-01, 1.8430e-05, 1.9339e-08, 1.7298e-09], device='cuda:0')

# %%
#Training the Image-based dog emotion classifier for 150 epochs
#model.train(data=r"C:\Users\sujay\Desktop\project_2\dog_image_dataset_preprocessed", epochs=150, imgsz=256)
# Out:
# New https://pypi.org/project/ultralytics/8.3.80 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.11.9 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
#Evaluation Metrics for the Image-based dog emotion classifier for 150 epochs
#model_path = r"runs\classify\train3\weights\best.pt"
#model = YOLO(model_path)
#class_labels = {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
#test_dir = r"C:\Users\sujay\Desktop\project_2\dog_image_dataset_preprocessed\val"
#y_true = []
#y_pred = []
#for class_name in class_labels.values():
#    class_path = os.path.join(test_dir, class_name)
#    if not os.path.exists(class_path):
#        continue
#    for filename in os.listdir(class_path):
#        if filename.endswith(('.jpg', '.png')):  
#            y_true.append(class_name)  
#            img_path = os.path.join(class_path, filename)
#           results = model(img_path)
#            predicted_index = results[0].probs.top1  
#            predicted_label = class_labels[predicted_index]              
#            y_pred.append(predicted_label)
#y_true = np.array(y_true)
#y_pred = np.array(y_pred)
#accuracy = accuracy_score(y_true, y_pred)
#precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted", zero_division=1)
#print(f"Accuracy: {accuracy:.4f}")
#print(f"Precision: {precision:.4f}")
#print(f"Recall: {recall:.4f}")
#print(f"F1 Score: {f1:.4f}")
# Out:
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0da4j6Ehkb6Ml0YBRiWmsBU2wEMoXP409.jpg: 256x256 angry 0.99, happy 0.01, relaxed 0.00, sad 0.00, 7.4ms
# Speed: 2.3ms preprocess, 7.4ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0jgI6KwR6IGvq9CAMBB3srLRa0W7z7192.jpg: 256x256 angry 0.99, happy 0.00, relaxed 0.00, sad 0.00, 3.9ms
# Speed: 1.9ms preprocess, 3.9ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0RXraPIKC00Dz1qkuMbj8XbuR80g5Z893.jpg: 256x256 angry 1.00, sad 0.00, happy 0.00, relaxed 0.00, 3.8ms
# Speed: 1.5ms preprocess, 3.8ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# ...

# %%
#Predictions

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train3\weights\best.pt")
image_path = r"To_be_predicted_images\images.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.64, sad 0.36, happy 0.00, angry 0.00, 17.9ms
# Speed: 1.1ms preprocess, 17.9ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([3.1101e-06, 7.5473e-05, 6.4053e-01, 3.5939e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.6405, device='cuda:0')
# top5: [2, 3, 1, 0]
# top5conf: tensor([6.4053e-01, 3.5939e-01, 7.5473e-05, 3.1101e-06], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train3\weights\best.pt")
image_path = r"To_be_predicted_images\images1.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.97, happy 0.02, angry 0.01, sad 0.00, 12.4ms
# Speed: 1.0ms preprocess, 12.4ms inference, 2.0ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([1.3245e-02, 2.1565e-02, 9.6514e-01, 4.9665e-05], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.9651, device='cuda:0')
# top5: [2, 1, 0, 3]
# top5conf: tensor([9.6514e-01, 2.1565e-02, 1.3245e-02, 4.9665e-05], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train3\weights\best.pt")
image_path = r"To_be_predicted_images\images2.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 sad 0.92, relaxed 0.08, happy 0.00, angry 0.00, 13.8ms
# Speed: 0.9ms preprocess, 13.8ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([5.6105e-06, 1.8686e-05, 8.0008e-02, 9.1997e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 3
# top1conf: tensor(0.9200, device='cuda:0')
# top5: [3, 2, 1, 0]
# top5conf: tensor([9.1997e-01, 8.0008e-02, 1.8686e-05, 5.6105e-06], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train3\weights\best.pt")
image_path = r"To_be_predicted_images\images3.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 angry 1.00, happy 0.00, relaxed 0.00, sad 0.00, 14.0ms
# Speed: 1.0ms preprocess, 14.0ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([1.0000e+00, 3.4233e-09, 3.2135e-10, 1.4679e-11], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 0
# top1conf: tensor(1., device='cuda:0')
# top5: [0, 1, 2, 3]
# top5conf: tensor([1.0000e+00, 3.4233e-09, 3.2135e-10, 1.4679e-11], device='cuda:0')

# %%
#Training the Image-based dog emotion classifier for 200 epochs
#model.train(data=r"C:\Users\sujay\Desktop\project_2\dog_image_dataset_preprocessed", epochs=200, imgsz=256)
# Out:
# New https://pypi.org/project/ultralytics/8.3.80 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.75  Python-3.11.9 torch-2.6.0+cu126 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
#Evaluation Metrics for the Image-based doe emotion classifer for 200 epochs
#model_path = r"runs\classify\train4\weights\best.pt"
#model = YOLO(model_path)
#class_labels = {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
#test_dir = r"dog_image_dataset_preprocessed\val"
#y_true = []
#y_pred = []
#for class_name in class_labels.values():
#    class_path = os.path.join(test_dir, class_name)
#    if not os.path.exists(class_path):
#        continue
#    for filename in os.listdir(class_path):
#        if filename.endswith(('.jpg', '.png')):  
#            y_true.append(class_name)  
#            img_path = os.path.join(class_path, filename)
#            results = model(img_path)
#            predicted_index = results[0].probs.top1  
#            predicted_label = class_labels[predicted_index]              
#            y_pred.append(predicted_label)
#y_true = np.array(y_true)
#y_pred = np.array(y_pred)
#accuracy = accuracy_score(y_true, y_pred)
#precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average="weighted", zero_division=1)
#print(f"Accuracy: {accuracy:.4f}")
#print(f"Precision: {precision:.4f}")
#print(f"Recall: {recall:.4f}")
#print(f"F1 Score: {f1:.4f}")
# Out:
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0da4j6Ehkb6Ml0YBRiWmsBU2wEMoXP409.jpg: 256x256 angry 1.00, happy 0.00, relaxed 0.00, sad 0.00, 5.5ms
# Speed: 3.2ms preprocess, 5.5ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0jgI6KwR6IGvq9CAMBB3srLRa0W7z7192.jpg: 256x256 angry 1.00, happy 0.00, sad 0.00, relaxed 0.00, 4.1ms
# Speed: 2.1ms preprocess, 4.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# image 1/1 C:\Users\sujay\Desktop\project_2\dog_emotion_dataset_preprocessed\val\angry\0RXraPIKC00Dz1qkuMbj8XbuR80g5Z893.jpg: 256x256 angry 1.00, sad 0.00, happy 0.00, relaxed 0.00, 3.6ms
# Speed: 1.7ms preprocess, 3.6ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 256)
#
# ...

# %%
#Predictions

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train4\weights\best.pt")
image_path = r"To_be_predicted_images\images.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 sad 0.82, relaxed 0.18, happy 0.00, angry 0.00, 4.5ms
# Speed: 0.4ms preprocess, 4.5ms inference, 0.5ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([2.2006e-10, 8.3026e-07, 1.7965e-01, 8.2035e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 3
# top1conf: tensor(0.8203, device='cuda:0')
# top5: [3, 2, 1, 0]
# top5conf: tensor([8.2035e-01, 1.7965e-01, 8.3026e-07, 2.2006e-10], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train4\weights\best.pt")
image_path = r"To_be_predicted_images\images1.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 happy 0.37, angry 0.33, relaxed 0.30, sad 0.00, 3.6ms
# Speed: 0.4ms preprocess, 3.6ms inference, 0.3ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([3.3323e-01, 3.6927e-01, 2.9749e-01, 5.3403e-06], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 1
# top1conf: tensor(0.3693, device='cuda:0')
# top5: [1, 0, 2, 3]
# top5conf: tensor([3.6927e-01, 3.3323e-01, 2.9749e-01, 5.3403e-06], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train4\weights\best.pt")
image_path = r"To_be_predicted_images\images2.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 relaxed 0.84, sad 0.16, happy 0.00, angry 0.00, 4.2ms
# Speed: 0.4ms preprocess, 4.2ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([4.1730e-09, 2.7844e-04, 8.4126e-01, 1.5846e-01], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 2
# top1conf: tensor(0.8413, device='cuda:0')
# top5: [2, 3, 1, 0]
# top5conf: tensor([8.4126e-01, 1.5846e-01, 2.7844e-04, 4.1730e-09], device='cuda:0')

# %%
def preprocess_for_yolo(image_path, model_size=(256, 256)):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_image = cv2.resize(image, model_size)
    stacked_image = np.stack([resized_image] * 3, axis=-1)
    normalized_image = stacked_image / 255.0
    processed_image = torch.tensor(normalized_image, dtype=torch.float32).permute(2, 0, 1)
    processed_image = processed_image.unsqueeze(0)
    return processed_image
model = YOLO(r"runs\classify\train4\weights\best.pt")
image_path = r"To_be_predicted_images\images3.jpg"
processed_image = preprocess_for_yolo(image_path)
results = model(processed_image)
print(results[0].names)
print(results[0].probs)
#model.predict(processed_image, save=True, imgsz=256, conf=0.5)
# Out:
# 0: 256x256 angry 1.00, happy 0.00, relaxed 0.00, sad 0.00, 4.8ms
# Speed: 1.0ms preprocess, 4.8ms inference, 0.4ms postprocess per image at shape (1, 3, 256, 256)
# {0: 'angry', 1: 'happy', 2: 'relaxed', 3: 'sad'}
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([1.0000e+00, 8.1051e-07, 1.9757e-10, 6.0755e-11], device='cuda:0')
# orig_shape: None
# shape: torch.Size([4])
# top1: 0
# top1conf: tensor(1.0000, device='cuda:0')
# top5: [0, 1, 2, 3]
# top5conf: tensor([1.0000e+00, 8.1051e-07, 1.9757e-10, 6.0755e-11], device='cuda:0')
